# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [12, 1, 3, 3]
y = [23, 24, 34, 5]
plt.plot(x, y, label='JKD', c='red')
plt.title("My first graph", fontdict={'fontname':'Comic Sans MS'})
plt.xlabel("X-Label")
plt.ylabel("Y-Laebl")
plt.legend()
plt.show()
